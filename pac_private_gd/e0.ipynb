# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
d = json.load(open('e0_values.json'))
keys = ['credit', 'mnist_0_vs_7', 'mnist_7_vs_9']

# %%
plt.hist(d['credit'])
# Out:
# (array([ 5.,  2., 15.,  2.,  0.,  0.,  1.,  1.,  0.,  1.]),
#  array([-0.06452926, -0.03507193, -0.00561459,  0.02384275,  0.05330009,
#          0.08275742,  0.11221476,  0.1416721 ,  0.17112944,  0.20058677,
#          0.23004411]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['mnist_0_vs_7'])
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0.,   1., 124.,   3.]),
#  array([-0.47188845, -0.41614395, -0.36039944, -0.30465493, -0.24891042,
#         -0.19316592, -0.13742141, -0.0816769 , -0.0259324 ,  0.02981211,
#          0.08555662]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(d['mnist_7_vs_9'])
# Out:
# (array([  1.,   0.,   1.,   2.,  10., 108.,   1.,   0.,   0.,   1.]),
#  array([-0.27345267, -0.22001193, -0.16657119, -0.11313046, -0.05968972,
#         -0.00624898,  0.04719176,  0.10063249,  0.15407323,  0.20751397,
#          0.26095471]),
#  <BarContainer object of 10 artists>)

# %%
for key in keys:
    imps = [abs(k) for k in d[key]]
    sorted_imps = sorted(imps)
    print(max(imps) / sum(sorted_imps[:-1]))
# Out:
# 0.31529768138140696
# 0.8590326441999104
# 0.24484073688832225
